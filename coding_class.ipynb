# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeshkannan/placement-training/blob/main/coding_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N=int(input("Enter max no. of candies:"))
K=int(input("Enter min no. of candies:"))
C=1
R=N
while(C==1):
  M=int(input("Enter amount of candies needed:"))
  if(M>N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# Enter max no. of candies:10
# Enter min no. of candies:5
# Enter amount of candies needed:7
# SOLD= 7
# Remaining= 10
# DO you want to continue(1or0):0

# %%
n=int(input("Enter total no. of monkeys:"))
k=int(input("Enter no. of banana monkey can eat:"))
j=int(input("Enter no. of peanut monkey can eat:"))
m=int(input("Enter total no. of banana:"))
p=int(input("Enter total no. of peanut:"))
if(k==0 or j==0):
  print("INVALID INPUT")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%k!=0):
    n=n-1
  print("No. of monkeys in tree:",n)
# Out:
# Enter total no. of monkeys:20
# Enter no. of banana monkey can eat:2
# Enter no. of peanut monkey can eat:3
# Enter total no. of banana:12
# Enter total no. of peanut:12
# No. of monkeys in tree: 10

# %%
print("Using Temp")
a,b=10,18
temp=a
a=b
b=temp
print(a,b)
print("Using ,")
a,b=25,30
a,b=b,a
print(a,b)
print("Using + and -")
a,b=42,20
a=a+b
b=a-b
a=a-b
print(a,b)
print("Using ^")
a,b=18,21
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# Using Temp
# 18 10
# Using ,
# 30 25
# Using + and -
# 20 42
# Using ^
# 21 18

# %%
user_input1=int(input("enter the number"))
user_input2=int(input("enter the number"))
user_input3=int(input("enter the number"))
largest=max(user_input1,user_input2,user_input3)
print("largest number is",largest)
# Out:
# enter the number56
# enter the number45
# enter the number78
# largest number is 78

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
largest=max(num)
print(num)
print("largest element is",largest)
# Out:
# enter the total no of elements3
# enter the number1
# enter the number2
# enter the number3
# [1, 2, 3]
# largest element is 3

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
smallest=min(num)
print(num)
print("smallest element is",smallest)
# Out:
# enter the total no of elements5
# enter the number10
# enter the number100
# enter the number1000
# enter the number999
# enter the number1
# [10, 100, 1000, 999, 1]
# smallest element is 1

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
print(num)
num.reverse()
print("reverse list is",num)
# Out:
# enter the total no of elements4
# enter the number1
# enter the number2
# enter the number3
# enter the number4
# [1, 2, 3, 4]
# reverse list is [4, 3, 2, 1]

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
print(num)
c=sum(num)
print("sum of elements is",c)
# Out:
# enter the total no of elements5
# enter the number1
# enter the number2
# enter the number3
# enter the number4
# enter the number5
# [1, 2, 3, 4, 5]
# sum of elements is 15

# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("LIST:",list)
# Out:
# Enter list size:4
# Enter the elements in the list1
# Enter the elements in the list2
# Enter the elements in the list3
# Enter the elements in the list4
# LIST: [1, 2, 3, 4]

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")

# %%
num=[]
total=int(input("enter the total no of elements"))
for i in range(total):
  numbers=int(input("enter the number"))
  num.append(numbers)
  largest=max(num)
print(num)
print("largest element is",largest)
max(num)==[]
print(largest)
# Out:
# enter the total no of elements3
# enter the number1
# enter the number2
# enter the number3
# [1, 2, 3]
# largest element is 3
# 3

# %%
list = []
n=int(input("Enter the number of elements: "))
for i in range(n):
  a=int(input("Enter element: "))
  list.append(a)
a=int(input("Enter the element for occurance"))
c=0
for i in range(n):
  if list[i]==a:
    c+=1
    print(c)
# Out:
# Enter the number of elements: 4
# Enter element: 1
# Enter element: 2
# Enter element: 3
# Enter element: 4
# Enter the element for occurance1
# 1

# %%
list=[]
n=int(input("Ener list size"))
for i in range(n):
  b=int(input("enter elements"))
  list.append(b)
c=int(input("Enter the element to be found="))
s=0
if c in list:
  for i in list:
    if c==i:
      s=s+1
  print("Found",s,"times")
else:
  print("Not found")
# Out:
# Ener list size3
# enter elements1
# enter elements1
# enter elements2
# Enter the element to be found=1
# Found 2 times

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
list.sort()
print(list)
print("Second largest element is:",list[-2])

# %%
i=map(int,(input("Enter elements:").split()))
print(list(i))
# Out:
# Enter elements:10 20 30
# [10, 20, 30]

# %%
arr =[10,20,30,40,50,60,70]
print(arr[1:6:3])
print(arr[:3])
print(arr[2:])
print(arr[::-1])
# Out:
# [20, 50]
# [10, 20, 30]
# [30, 40, 50, 60, 70]
# [70, 60, 50, 40, 30, 20, 10]

# %%
r=int(input("No of rats:"))
u=int(input("No of units:"))
n=int(input("No of elements:"))
arr=list(map(int,input("Enter array").split()))
sum=0
h=0
for i in range(0,len(arr)):
  h+=1
  sum=sum+arr[i]
  if sum>=r*u:
    break
print("No of houses:",h)

# %%
r = int(input("Enter number of rats: "))
unit = int(input("Enter amount of food each rat eats: "))
n = int(input("Enter number of houses: "))
arr = list(map(int, input("Enter food in each house: ").split()))
if arr is None:
    print(-1)
else:
    required = r * unit
    total = 0
    houses = 0
    for i in range(n):
        total = total + arr[i]
        houses = houses + 1
        if total >= required:
            break
    if total < required:
        print(0)
    else:
        print("Minimum number of houses:", houses)

# %%
s=input("enter a string:")
print(s[::-1])
# Out:
# enter a string:123
# 321

# %%
n=int(input("enter a number"))
reversed_number=int(string(n)[::-1])

print("reversed string",reversed_number)

# %%
n = int(input("Enter a number: "))
largest = 0
while n > 0:
    digit = n % 10
    if digit > largest:
        largest = digit
    n = n // 10
print("Largest digit:", largest)

# %%
a=int(input("Enter your number:"))
sum=0
while a>0:
  num=a%10
  sum=sum+num
  a=a//10
print("Sum of digits is:",sum)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18390/1118200024.py in <cell line: 0>()
# ----> 1 a=int(input("Enter your number:"))
#       2 sum=0
#       3 while a>0:
#       4   num=a%10
#       5   sum=sum+num
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
s=input("Ënter a string:")
v=0
c=0
for i in s:
  if(i in "aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels:",v)
print("No of consonants:",c)

# %%
s = input("Enter a string: ")
result = ""
for ch in s:
    if ch not in result:
        result += ch
print(result)

# %%
N1=int(input("enter the no of strong positions on road A:"))
N2=int(input("enter the no of strong positions on road B:"))
a=[int(input("enter the strong positions on road A:")) for i in range(N1)]
b=[int(input("enter the strong positions on road B:")) for i in range(N2)]
s=sorted(set(a+b))
print(s)
N=len(s)
if N%2==1:
  print(s[N//2])
else:
  print((s[N//2-1]+s[N//2])/2)
# Out:
# enter the no of strong positions on road A:2
# enter the no of strong positions on road B:3
# enter the strong positions on road A:1
# enter the strong positions on road A:2
# enter the strong positions on road B:3
# enter the strong positions on road B:4
# enter the strong positions on road B:5
# [1, 2, 3, 4, 5]
# 3

# %%
print("ab","cd","ef")
printf("ab","cd","ef")
# Out:
# ab cd ef
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34070/770714955.py in <cell line: 0>()
#       1 print("ab","cd","ef")
# ----> 2 printf("ab","cd","ef")
#
# NameError: name 'printf' is not defined

# %%
printf(5+"ef")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34070/4001522894.py in <cell line: 0>()
# ----> 1 printf(5+"ef")
#
# NameError: name 'printf' is not defined

# %%
n=int(input("Enter number:"))
a=bin(n)
b=a[2:]
b=b.replace('0','y').replace('1','0').replace('y','1')
print(int(b,2))
# Out:
# Enter number:65
# 62
